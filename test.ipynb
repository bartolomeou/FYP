# %%
from src.mcmc.mcmc import SMBarker as aSMBarker

from src.mcmc.smbarker import SMBarker

from src.dist.rosenbrock import Rosenbrock

from src.utils.plot import traceplot, acfplot

# %%
target = Rosenbrock(n1=2, n2=2)

# %%
X_rwm, accept_rate = SMBarker(target, 1000, x_init=[0, 0, 0])

print(accept_rate)
traceplot(X_rwm)
acfplot(X_rwm)
# Out:
# 0.669

# %%
mcmc = aSMBarker()
a = mcmc.sample(
    target=target,
    initial_state=[0, 0, 0],
    n_main_iter=1000,
    n_burnin_iter=0,
    adapter=None,
)

print(a["accept_rate"])
traceplot(a["trace_main"])
acfplot(a["trace_main"])
# Out:
# 0.672
