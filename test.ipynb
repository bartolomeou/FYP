# %%
import numpy as np
import seaborn as sns

import random

from src.mcmc import RandomWalk, Barker, SMBarker, MALA, SMMALA, MMALA

from src.distribution import Rosenbrock, SmoothedGeneralNormal

from src.utils.plot import traceplot, acfplot, rosenbrock_pairplot

# %%
mcmc = MMALA()

# %%
target = SmoothedGeneralNormal(beta=4)

a = mcmc.sample(target=target)

traceplot(a["trace_main"])

# %%
# target = Rosenbrock(n_var=3, n1=3, n2=1)

# b = mcmc.sample(target=target)
# traceplot(b["trace_main"])
